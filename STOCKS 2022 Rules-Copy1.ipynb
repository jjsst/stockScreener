# %%
#importing packages
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import bs4 as bs
import requests
import os
from yahoo_fin import stock_info as si
import talib as tlib
import pandas_ta as taa
from bs4 import BeautifulSoup as soup
from urllib.request import Request, urlopen
from docx import Document
from docx.shared import Cm , Pt
from pandas import ExcelWriter
from openpyxl import load_workbook
from ta.utils import dropna
from ta.volatility import BollingerBands
import re
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials
import seaborn as sns

sns.set()
pd.set_option('display.max_colwidth', 25)
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', '{:.2f}'.format)

tickers = []

excel_stock_ark_data_df = pd.read_excel('Stocks.xlsx', sheet_name='sheet_stocks')

tickers = excel_stock_ark_data_df['ticker'].tolist()

all_data = pd.DataFrame()
test_data = pd.DataFrame()
test_fin = pd.DataFrame()

no_data = []

#Extract data from Yahoo Finance


cnt=0
for i in tickers:

    cnt = cnt + 1
    print(str(i) + ' nº ' + str(cnt))
    test_data = yf.download(i, start=dt.datetime(2020,1,1), end = dt.date.today(), progress=False)  
    test_data['symbol'] = i

#     try:        
#         objstock = yf.Ticker(i)
#         info = objstock.info
#         test_data['sector'] = info['sector']     
#         test_data['name'] = info['shortName']              
#     except Exception as e:
#         print(e)  

    open = test_data['Open']
    high  = test_data['High']
    low  = test_data['Low']
    close  = test_data['Close']
    volume = test_data['Volume']
    test_data['ema20'] = tlib.EMA(close, timeperiod=20)
    test_data['ema20'] = test_data['ema20'].round(decimals = 2)
    test_data['rsi14'] = tlib.RSI(close, timeperiod=14)
    test_data['rsi14'] = test_data['rsi14'].round(decimals = 2)
    test_data['mfi12'] = tlib.MFI(high, low, close, volume, timeperiod=12)
    test_data['mfi12'] = test_data['mfi12'].round(decimals = 2)    
    test_data['cdle_hammer'] = tlib.CDLHAMMER(open, high, low, close)   
    test_data['cdle_haramicross'] = tlib.CDLHARAMICROSS(open, high, low, close)
    test_data['cdle_piercing'] = tlib.CDLPIERCING(open, high, low, close)
    test_data['cdle_engulfing'] = tlib.CDLENGULFING(open, high, low, close)     
    test_data['cdle_3blackcrows'] = tlib.CDL3BLACKCROWS(open, high, low, close)
    test_data['cdle_darkcloudcover'] = tlib.CDLDARKCLOUDCOVER(open, high, low, close, penetration=0)
    test_data['cdle_hangingman'] = tlib.CDLHANGINGMAN(open, high, low, close)
    test_data['cdle_eveningstar'] = tlib.CDLEVENINGSTAR(open, high, low, close, penetration=0)
    test_data["ValHigh_of_365Days"]= tlib.MAX(close, timeperiod=365)
    test_data["DayHigh_of_365Days"]= tlib.MAXINDEX(close, timeperiod=365)
    test_data["ValLow_of_365Days"]= tlib.MIN(close, timeperiod=365)
    test_data["DayLow_of_365Days"]= tlib.MININDEX(close, timeperiod=365)    

    
    test_data = test_data.dropna().copy()
    all_data = all_data.append(test_data)


all_data_current = all_data.groupby('symbol').tail(1)

# escreve para ficheiro
data = datetime.today().strftime('%Y-%m-%d')
all_data_current.to_excel(r'AnaliseDiaria '+data+ '.xlsx', index = True)  # para copiar a data coluna index
# Out:
# A nº 1
# AAL nº 2
# AAPL nº 3
# ABNB nº 4
# ADBE nº 5
# AFRM nº 6
# AMLP nº 7
# AMZN nº 8
# APA nº 9
# ATSG nº 10
# AWAY nº 11
# AXP nº 12
# BAC nº 13
# BDRY nº 14
# BG nº 15
# BJK nº 16
# BKNG nº 17
# BMY nº 18
# BNTX nº 19
# BP nº 20
# BSX nº 21
# BUG nº 22
# BWA nº 23
# CAT nº 24
# CCL nº 25
# CF nº 26
# CL nº 27
# COIN nº 28
# COPX nº 29
# COST nº 30
# CPER nº 31
# CRM nº 32
# CRWD nº 33
# CSCO nº 34
# CTRA nº 35
# CVX nº 36
# DBB nº 37
# DE nº 38
# DFEN nº 39
# DHR nº 40
# DIS nº 41
# DRIV nº 42
# DTE nº 43
# DVN nº 44
# DVY nº 45
# EL nº 46
# EL nº 47
# EOG nº 48
# F nº 49
# FANG nº 50
# FB nº 51
# FCX nº 52
# FISV nº 53
# GDX nº 54
# GM nº 55
# GS nº 56
# GSG nº 57
# GSK nº 58
# HACK nº 59
# HAUS nº 60
# HGER nº 61
# IHAK nº 62
# IHI nº 63
# ISRG nº 64
# ITA nº 65
# JETS nº 66
# JNJ nº 67
# KHC nº 68
# KR nº 69
# KRE nº 70
# KWEB nº 71
# LIN nº 72
# LLY nº 73
# LRCX nº 74
# LVS nº 75
# MA nº 76
# MCD nº 77
# MGM nº 78
# MJ nº 79
# MOS nº 80
# MP nº 81
# MRNA nº 82
# MRVL nº 83
# MS nº 84
# MSFT nº 85
# MSGE nº 86
# MTD nº 87
# MTUM nº 88
# MXI nº 89
# NCLH nº 90
# NFLX nº 91
# NUE nº 92
# NVDA nº 93
# NVS nº 94
# OAS nº 95
# PALL nº 96
# PANW nº 97
# PFE nº 98
# PFIX nº 99
# PLD nº 100
# PLTR nº 101
# PXD nº 102
# PYPL nº 103
# QCLN nº 104
# RH nº 105
# RIO nº 106
# RJA nº 107
# SCHH nº 108
# SCHW nº 109
# SNOW nº 110
# SNX nº 111
# SOXX nº 112
# SQ nº 113
# SQ nº 114
# TGT nº 115
# TMO nº 116
# TSLA nº 117
# TSM nº 118
# UAL nº 119
# UPST nº 120
# URNM nº 121
# USO nº 122
# VHT nº 123
# VLO nº 124
# VV nº 125
# WFC nº 126
# WMT nº 127
# WYNN nº 128
# XBI nº 129
# XHB nº 130
# XLB nº 131
# XLC nº 132
# XLE nº 133
# XLI nº 134
# XLK nº 135
# XLP nº 136
# XLU nº 137
# XLV nº 138
# XME nº 139
# XOM nº 140
# XOP nº 141
# XRT nº 142
# XSD nº 143

# %%
all_data
# Out:
#              Open   High    Low  Close  Adj Close   Volume symbol  ema20  \
# Date
# 2021-06-14 143.50 144.43 142.76 144.39     143.61   934200      A 137.65
# 2021-06-15 144.85 145.16 144.04 144.62     143.83  1035800      A 138.32
# 2021-06-16 144.66 145.08 142.92 143.59     142.81  1680800      A 138.82
# 2021-06-17 143.49 147.68 143.49 146.92     146.12  2822400      A 139.59
# 2021-06-18 146.31 146.83 144.94 145.01     144.22  3220700      A 140.11
# ...           ...    ...    ...    ...        ...      ...    ...    ...
# 2022-04-04 204.37 207.83 204.01 207.13     207.13    94700    XSD 205.92
# 2022-04-05 205.70 206.05 195.09 195.53     195.53   277000    XSD 204.93
# 2022-04-06 192.04 192.39 187.81 189.01     189.01   196300    XSD 203.41
# 2022-04-07 188.56 191.87 184.00 188.27     188.27    99800    XSD 201.97
# 2022-04-08 187.12 187.43 182.88 183.03     183.03    85800    XSD 200.17
#
#             rsi14  mfi12  ...  cdle_piercing  cdle_engulfing  \
# Date                      ...
# 2021-06-14  75.75  67.70  ...              0               0
# 2021-06-15  76.11  62.02  ...              0               0
# 2021-06-16  71.03  51.62  ...              0               0
# 2021-06-17  76.49  67.09  ...              0             100
# 2021-06-18  68.51  59.61  ...              0               0
# ...           ...    ...  ...            ...             ...
# 2022-04-04  51.39  52.27  ...              0               0
# 2022-04-05  43.58  41.87  ...              0               0
# 2022-04-06  39.91  35.29  ...              0               0
# 2022-04-07  39.51  30.71  ...              0               0
# 2022-04-08  36.66  30.98  ...              0               0
#
#             cdle_3blackcrows  cdle_darkcloudcover  cdle_hangingman  \
# Date
# 2021-06-14                 0                    0                0
# 2021-06-15                 0                    0                0
# 2021-06-16                 0                    0                0
# 2021-06-17                 0                    0                0
# 2021-06-18                 0                    0                0
# ...                      ...                  ...              ...
# 2022-04-04                 0                    0                0
# 2022-04-05                 0                    0                0
# 2022-04-06                 0                    0                0
# 2022-04-07                 0                    0                0
# 2022-04-08                 0                    0                0
#
#             cdle_eveningstar  ValHigh_of_365Days  DayHigh_of_365Days  \
# Date
# 2021-06-14                 0              144.39                 364
# 2021-06-15                 0              144.62                 365
# 2021-06-16              -100              144.62                 365
# 2021-06-17                 0              146.92                 367
# 2021-06-18                 0              146.92                 367
# ...                      ...                 ...                 ...
# 2022-04-04                 0              248.86                 488
# 2022-04-05                 0              248.86                 488
# 2022-04-06                 0              248.86                 488
# 2022-04-07                 0              248.86                 488
# 2022-04-08                 0              248.86                 488
#
#             ValLow_of_365Days  DayLow_of_365Days
# Date
# 2021-06-14              63.37                 55
# 2021-06-15              63.37                 55
# 2021-06-16              63.37                 55
# 2021-06-17              63.37                 55
# 2021-06-18              63.37                 55
# ...                       ...                ...
# 2022-04-04             129.54                208
# 2022-04-05             129.54                208
# 2022-04-06             129.54                208
# 2022-04-07             129.54                208
# 2022-04-08             129.54                208
#
# [27843 rows x 22 columns]

# %%
dhr = yf.Ticker('QCLN')
info = dhr.info
info.keys()
info['longName']

# %%
del all_data_current['Low']
del all_data_current['High']
del all_data_current['Open']

# escreve para ficheiro
data = datetime.today().strftime('%Y-%m-%d')
all_data_current.to_excel(r'AnaliseDiaria '+data+ '.xlsx', index = True)  # para copiar a data coluna index

# %%
help(taa.donchian)

# %%
test_data

# %%
all_data_current.to_excel(r'DadosMercado_30dez2020.xlsx', index = True)  # para copiar a data coluna index

# %%
all_data

# %%
all_data1 = all_data

# %%
all_data = all_data1

# %%
import pandas_ta as ta
help(ta.adosc)

# %%
# # Create a DataFrame so 'ta' can be used.
# df = pd.DataFrame()

# # Help about this, 'ta', extension
# help(df.ta)

# List of all indicators
test_data.ta.indicators()

# # Help about the log_return indicator
# help(ta.log_return)

# %%
help(ta.variance)

# %%
test_data = pdr.get_data_yahoo("AAPL", start = dt.datetime(2020,1,1), end = dt.date.today())
test_data['DATA'] = test_data.index

test_data.drop(test_data[test_data['DATA'].dt.dayofweek == 1].index)

# %%
test_data

# %%
all_data_current

# %%
all_data

# %%
# escreve para ficheiro
data = datetime.today().strftime('%Y-%m-%d')
all_data_current.to_excel(r'AnaliseDiaria '+data+ '.xlsx', index = True)  # para copiar a data coluna index
